# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c1c16e9b-f00c-4566-91cf-ad41a6764560" name="files[]" multiple disabled />
#      <output id="result-c1c16e9b-f00c-4566-91cf-ad41a6764560">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wiki_sentences_v2.csv to wiki_sentences_v2.csv

# %%
# import wikipedia sentences
candidate_sentences = pd.read_csv("wiki_sentences_v2.csv")
candidate_sentences.shape
# Out:
# (4318, 1)

# %%
candidate_sentences['sentence'].sample(5)
# Out:
# 2989                                           a number of film gauges were made.
# 3728                                  but the film ended up making $66.3 million.
# 2120    a clockwork orange remains an influential work in cinema and other media.
# 3799                 fukunaga was announced as boyle's replacement a month later.
# 3490             the family now live in both chiswick, london, and umbria, italy.
# Name: sentence, dtype: object

# %%
doc = nlp("the drawdown process is governed by astm standard d823")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# the ... det
# drawdown ... compound
# process ... nsubjpass
# is ... auxpass
# governed ... ROOT
# by ... agent
# astm ... compound
# standard ... pobj
# d823 ... punct

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["sentence"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 4318/4318 [00:39<00:00, 109.57it/s]

# %%
entity_pairs[10:20]
# Out:
# [['we', 'tests'],
#  ['global', 'international sales rights'],
#  ['robbie  robertson', 'soundtrack'],
#  ['it', 'original music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['military  forces', 'arrest'],
#  ['train', 'vuk'],
#  ['kota eberhardt', 'telepath selene gallio'],
#  ['singer', 'sequel']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add("matching_1", None, pattern) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
# Out:
# 100%|██████████| 4318/4318 [00:38<00:00, 113.29it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# is               368
# was              283
# released on       79
# are               72
# include           69
# were              63
# 's                42
# released          41
# have              30
# has               30
# composed by       29
# became            29
# released in       28
# become            28
# considered        22
# included          21
# had               19
# be                19
# produced          19
# called            19
# used              18
# stars             18
# been              18
# scheduled         17
# made              16
# directed by       15
# wrote             14
# set               14
# went              14
# hired             14
# introduced in     13
# written by        13
# received          13
# sold              12
# wanted            12
# won               11
# cast as           11
# began in          10
# produced by       10
# began             10
# includes          10
# features          10
# gave              10
# gives              9
# opened             9
# shot in            9
# directed           9
# used in            9
# reported           9
# revealed           8
# dtype: int64

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     487                                            iterations, threshold,
# --> 488                                            dim, seed)
#     489     except:
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-830> in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#
# /usr/local/lib/python3.6/dist-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/layout.py in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     623             # distance between points
# --> 624             distance = np.sqrt((delta**2).sum(axis=0))
#     625             # enforce minimum distance of 0.01
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-cdcc3233b4da> in <module>()
#       1 plt.figure(figsize=(12,12))
#       2
# ----> 3 pos = nx.spring_layout(G)
#       4 nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
#       5 plt.show()
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-826> in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#
# /usr/local/lib/python3.6/dist-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     403         new_args = list(args)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#     407
#
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     494             k = dom_size / np.sqrt(nnodes)
#     495         pos = _fruchterman_reingold(A, k, pos_arr, fixed, iterations,
# --> 496                                     threshold, dim, seed)
#     497     if fixed is None and scale is not None:
#     498         pos = rescale_layout(pos, scale=scale) + center
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-828> in _fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#
# /usr/local/lib/python3.6/dist-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     403         new_args = list(args)
#     404         new_args[random_state_index] = random_state
# --> 405         return func(*new_args, **kwargs)
#     406     return _random_state
#     407
#
# /usr/local/lib/python3.6/dist-packages/networkx/drawing/layout.py in _fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     541     for iteration in range(iterations):
#     542         # matrix of difference between points
# --> 543         delta = pos[:, np.newaxis, :] - pos[np.newaxis, :, :]
#     544         # distance between points
#     545         distance = np.linalg.norm(delta, axis=-1)
#
# KeyboardInterrupt:

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='pink', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="written by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="released in"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5)
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
